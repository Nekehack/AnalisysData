# %%
import pandas as pd
from transformers import AutoTokenizer, TFAutoModelForQuestionAnswering, pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Задание 1 Анализ производительности QA-модели

# Загрузка и преобразование датасета из 10 предложений и по 3 вопроса к каждому
data = pd.read_csv('/Users/ilia/ATAT/Sem9/Без названия 2.csv', sep=';') # Локальный путь к файлу "Без названия 2.csv"
print(data)
contexts = data['Текст'].tolist()  # Извлекаем столбец 'Текст'
questions_1 = data['Вопрос1'].tolist()  # Извлекаем столбец 'вопрос1'
questions_2 = data['Вопрос2'].tolist()  # Извлекаем столбец 'вопрос2'
questions_3 = data['Вопрос3'].tolist()

# print(contexts[0])
# Out:
#                                                Текст  \
# 0  The sun is the star at the center of our solar...
# 1  Elephants are the largest land animals. They h...
# 2  The Eiffel Tower was completed in 1889 as the ...
# 3  Water boils at 100°C at sea level. However, at...
# 4  The Amazon Rainforest is home to millions of s...
# 5  The Great Wall of China stretches over 13,000 ...
# 6  William Shakespeare was an English playwright ...
# 7  The Pacific Ocean is the largest and deepest o...
# 8  The human brain consists of billions of neuron...
# 9  The Mona Lisa is a famous painting by Leonardo...
#
#                                              Вопрос1  \
# 0                                   What is the sun?
# 1                   What is the largest land animal?
# 2             When was the Eiffel Tower completed?\n
# 3  At what temperature does water boil at sea lev...
# 4            Where is the Amazon Rainforest located?
# 5             How long is the Great Wall of China?\n
# 6                     Who was William Shakespeare?\n
# 7                What is the largest ocean on Earth?
# 8            What does the human brain consist of?\n
# 9                       Who painted the Mona Lisa?\n
#
#                                         Вопрос2  \
# 0            How does the sun provide energy?\n
# 1               How do elephants communicate?\n
# 2                  What event was it built for?
# 3       How does altitude affect boiling point?
# 4  Why is the Amazon important for the climate?
# 5               Why was the Great Wall built?\n
# 6       Name two of Shakespeare’s famous works.
# 7               How big is the Pacific Ocean?\n
# 8    How does the brain transmit information?\n
# 9        What is special about the Mona Lisa?\n
#
#                                              Вопрос3
# 0                    What process occurs in the sun?
# 1                                What is infrasound?
# 2                 Where is the Eiffel Tower located?
# 3  Why does atmospheric pressure change boiling p...
# 4  What types of organisms live in the Amazon Rai...
# 5       When did the construction of the wall begin?
# 6        How did Shakespeare influence literature?\n
# 7  What kind of life can be found in the Pacific ...
# 8        What are the main functions of the brain?\n
# 9                  Where is the Mona Lisa displayed?

# %%
# Загрузка модели MiniLM и токенизатора
model_id_minilm = 'deepset/minilm-uncased-squad2'
tokenizer_minilm = AutoTokenizer.from_pretrained(model_id_minilm)
model_minilm = TFAutoModelForQuestionAnswering.from_pretrained(model_id_minilm, from_pt=True)
qa_pipeline_minilm = pipeline('question-answering', model=model_minilm, tokenizer=tokenizer_minilm)

# Обучение модели модели MiniLM на основе датасета
def get_answers(contexts, questions):
    for i, context in enumerate(contexts):
        print(f"Текст {i + 1}: {context[:100]}...")  # Печатаем начало текста
        for j, question in enumerate([questions_1[i], questions_2[i], questions_3[i]]):
            output = qa_pipeline_minilm(question=question, context=context, handle_impossible_answer=True)
            # Выводы
            if output['start'] != output['end']:
                print(f"  Вопрос {j + 1}: {question}")
                print(f"  Ответ: {output['answer']} (Оценка: {output['score']:.1%})")
            else:
                print(f"  Вопрос {j + 1}: {question} -> Нет ответа")
        print("-" * 50)

# Тестирование модели
get_answers(contexts, [questions_1, questions_2, questions_3])
# Out:
# All PyTorch model weights were used when initializing TFBertForQuestionAnswering.
#
# All the weights of TFBertForQuestionAnswering were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertForQuestionAnswering for predictions without further training.
# Device set to use 0
# Текст 1: The sun is the star at the center of our solar system. It provides the energy necessary for life on ...
#   Вопрос 1: What is the sun?
#   Ответ: the star at the center of our solar system (Оценка: 54.5%)
#   Вопрос 2: How does the sun provide energy?
#
#   Ответ: nuclear fusion (Оценка: 60.8%)
#   Вопрос 3: What process occurs in the sun?
#   Ответ: nuclear fusion (Оценка: 96.4%)
# --------------------------------------------------
# Текст 2: Elephants are the largest land animals. They have strong social bonds and communicate using infrasou...
#   Вопрос 1: What is the largest land animal?
#   Ответ: Elephants (Оценка: 99.6%)
#   Вопрос 2: How do elephants communicate?
#
#   Ответ: infrasound (Оценка: 64.0%)
#   Вопрос 3: What is infrasound?
#   Ответ: inaudible to humans (Оценка: 81.0%)
# --------------------------------------------------
# Текст 3: The Eiffel Tower was completed in 1889 as the entrance arch for the World's Fair in Paris. It remain...
#   Вопрос 1: When was the Eiffel Tower completed?
#
#   Ответ: 1889 (Оценка: 97.8%)
#   Вопрос 2: What event was it built for?
#   Ответ: the World's Fair (Оценка: 46.5%)
#   Вопрос 3: Where is the Eiffel Tower located?
#   Ответ: Paris (Оценка: 98.1%)
# --------------------------------------------------
# Текст 4: Water boils at 100°C at sea level. However, at higher altitudes, the boiling point decreases due to ...
#   Вопрос 1: At what temperature does water boil at sea level?
#
#   Ответ: 100°C (Оценка: 97.7%)
#   Вопрос 2: How does altitude affect boiling point?
#   Ответ: decreases (Оценка: 75.0%)
#   Вопрос 3: Why does atmospheric pressure change boiling point?
#  -> Нет ответа
# --------------------------------------------------
# Текст 5: The Amazon Rainforest is home to millions of species of plants and animals. It plays a crucial role ...
#   Вопрос 1: Where is the Amazon Rainforest located? -> Нет ответа
#   Вопрос 2: Why is the Amazon important for the climate?
#   Ответ: producing oxygen (Оценка: 43.4%)
#   Вопрос 3: What types of organisms live in the Amazon Rainforest?
#
#   Ответ: plants and animals (Оценка: 94.9%)
# --------------------------------------------------
# Текст 6: The Great Wall of China stretches over 13,000 miles and was built to protect Chinese states from inv...
#   Вопрос 1: How long is the Great Wall of China?
#
#   Ответ: over 13,000 miles (Оценка: 55.2%)
#   Вопрос 2: Why was the Great Wall built?
#
#   Ответ: to protect Chinese states from invasions (Оценка: 76.8%)
#   Вопрос 3: When did the construction of the wall begin?
#   Ответ: 7th century BC (Оценка: 55.6%)
# --------------------------------------------------
# Текст 7: William Shakespeare was an English playwright and poet, known for works like "Hamlet" and "Romeo and...
#   Вопрос 1: Who was William Shakespeare?
#
#   Ответ: an English playwright and poet (Оценка: 47.0%)
#   Вопрос 2: Name two of Shakespeare’s famous works.
#   Ответ: Hamlet" and "Romeo and Juliet." (Оценка: 30.8%)
#   Вопрос 3: How did Shakespeare influence literature?
#
#   Ответ: immense (Оценка: 91.8%)
# --------------------------------------------------
# Текст 8: The Pacific Ocean is the largest and deepest ocean on Earth, covering more than 63 million square mi...
#   Вопрос 1: What is the largest ocean on Earth?
#   Ответ: The Pacific Ocean (Оценка: 54.3%)
#   Вопрос 2: How big is the Pacific Ocean?
#
#   Ответ: 63 million square miles (Оценка: 48.4%)
#   Вопрос 3: What kind of life can be found in the Pacific Ocean?
#
#
#   Ответ: marine life (Оценка: 52.2%)
# --------------------------------------------------
# Текст 9: The human brain consists of billions of neurons that transmit electrical and chemical signals. It co...
#   Вопрос 1: What does the human brain consist of?
#
#   Ответ: billions of neurons (Оценка: 78.8%)
#   Вопрос 2: How does the brain transmit information?
#
#   Ответ: electrical and chemical signals (Оценка: 66.7%)
#   Вопрос 3: What are the main functions of the brain?
#
#   Ответ: bodily functions and cognitive processes (Оценка: 40.9%)
# --------------------------------------------------
# Текст 10: The Mona Lisa is a famous painting by Leonardo da Vinci. It is known for its mysterious smile and is...
#   Вопрос 1: Who painted the Mona Lisa?
#
#   Ответ: Leonardo da Vinci (Оценка: 96.2%)
#   Вопрос 2: What is special about the Mona Lisa?
#
#   Ответ: mysterious smile (Оценка: 55.0%)
#   Вопрос 3: Where is the Mona Lisa displayed?
#   Ответ: the Louvre Museum in Paris (Оценка: 36.5%)
# --------------------------------------------------

# %%
# Задание 2: Тестирование других моделей
# Загрузка модели BERT и токенизатора
model_id_bert = 'bert-large-uncased-whole-word-masking-finetuned-squad'
tokenizer_bert = AutoTokenizer.from_pretrained(model_id_bert)
model_bert = TFAutoModelForQuestionAnswering.from_pretrained(model_id_bert, from_pt=True)
qa_pipeline_bert = pipeline('question-answering', model=model_bert, tokenizer=tokenizer_bert)

# Функция для тестирования модели BERT
def test_bert(contexts, questions):
    for i, context in enumerate(contexts):
        print(f"Текст {i + 1}: {context[:100]}...")  # Печатаем начало текста
        for j, question in enumerate([questions_1[i], questions_2[i], questions_3[i]]):
            output = qa_pipeline_bert(question=question, context=context, handle_impossible_answer=True)
            if output['start'] != output['end']:
                print(f"  Вопрос {j + 1}: {question}")
                print(f"  Ответ: {output['answer']} (Оценка: {output['score']:.1%})")
            else:
                print(f"  Вопрос {j + 1}: {question} -> Нет ответа")
        print("-" * 50)

# Тестирование модели BERT
test_bert(contexts, [questions_1, questions_2, questions_3])
# Out:
# All PyTorch model weights were used when initializing TFBertForQuestionAnswering.
#
# All the weights of TFBertForQuestionAnswering were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertForQuestionAnswering for predictions without further training.
# Device set to use 0
# Текст 1: The sun is the star at the center of our solar system. It provides the energy necessary for life on ...
#   Вопрос 1: What is the sun?
#   Ответ: the star at the center of our solar system (Оценка: 63.2%)
#   Вопрос 2: How does the sun provide energy?
#
#   Ответ: nuclear fusion (Оценка: 71.8%)
#   Вопрос 3: What process occurs in the sun?
#   Ответ: nuclear fusion (Оценка: 90.9%)
# --------------------------------------------------
# Текст 2: Elephants are the largest land animals. They have strong social bonds and communicate using infrasou...
#   Вопрос 1: What is the largest land animal?
#   Ответ: Elephants (Оценка: 99.9%)
#   Вопрос 2: How do elephants communicate?
#
#   Ответ: infrasound (Оценка: 52.1%)
#   Вопрос 3: What is infrasound?
#   Ответ: inaudible to humans (Оценка: 90.4%)
# --------------------------------------------------
# Текст 3: The Eiffel Tower was completed in 1889 as the entrance arch for the World's Fair in Paris. It remain...
#   Вопрос 1: When was the Eiffel Tower completed?
#
#   Ответ: 1889 (Оценка: 99.4%)
#   Вопрос 2: What event was it built for?
#   Ответ: World's Fair (Оценка: 54.5%)
#   Вопрос 3: Where is the Eiffel Tower located?
#   Ответ: Paris (Оценка: 98.8%)
# --------------------------------------------------
# Текст 4: Water boils at 100°C at sea level. However, at higher altitudes, the boiling point decreases due to ...
#   Вопрос 1: At what temperature does water boil at sea level?
#
#   Ответ: 100°C (Оценка: 99.6%)
#   Вопрос 2: How does altitude affect boiling point?
#   Ответ: lower atmospheric pressure (Оценка: 54.6%)
#   Вопрос 3: Why does atmospheric pressure change boiling point?
#
#   Ответ: lower atmospheric pressure (Оценка: 48.0%)
# --------------------------------------------------
# Текст 5: The Amazon Rainforest is home to millions of species of plants and animals. It plays a crucial role ...
#   Вопрос 1: Where is the Amazon Rainforest located?
#   Ответ: Amazon (Оценка: 76.9%)
#   Вопрос 2: Why is the Amazon important for the climate?
#   Ответ: producing oxygen (Оценка: 62.6%)
#   Вопрос 3: What types of organisms live in the Amazon Rainforest?
#
#   Ответ: plants and animals (Оценка: 91.3%)
# --------------------------------------------------
# Текст 6: The Great Wall of China stretches over 13,000 miles and was built to protect Chinese states from inv...
#   Вопрос 1: How long is the Great Wall of China?
#
#   Ответ: 13,000 miles (Оценка: 77.2%)
#   Вопрос 2: Why was the Great Wall built?
#
#   Ответ: to protect Chinese states from invasions (Оценка: 81.6%)
#   Вопрос 3: When did the construction of the wall begin?
#   Ответ: 7th century BC (Оценка: 64.1%)
# --------------------------------------------------
# Текст 7: William Shakespeare was an English playwright and poet, known for works like "Hamlet" and "Romeo and...
#   Вопрос 1: Who was William Shakespeare?
#
#   Ответ: an English playwright and poet (Оценка: 58.8%)
#   Вопрос 2: Name two of Shakespeare’s famous works.
#   Ответ: Hamlet" and "Romeo and Juliet." (Оценка: 40.9%)
#   Вопрос 3: How did Shakespeare influence literature?
#
#   Ответ: immense (Оценка: 57.8%)
# --------------------------------------------------
# Текст 8: The Pacific Ocean is the largest and deepest ocean on Earth, covering more than 63 million square mi...
#   Вопрос 1: What is the largest ocean on Earth?
#   Ответ: The Pacific Ocean (Оценка: 55.5%)
#   Вопрос 2: How big is the Pacific Ocean?
#
#   Ответ: 63 million square miles (Оценка: 59.6%)
#   Вопрос 3: What kind of life can be found in the Pacific Ocean?
#
#
#   Ответ: diverse marine life (Оценка: 55.7%)
# --------------------------------------------------
# Текст 9: The human brain consists of billions of neurons that transmit electrical and chemical signals. It co...
#   Вопрос 1: What does the human brain consist of?
#
#   Ответ: billions of neurons (Оценка: 67.7%)
#   Вопрос 2: How does the brain transmit information?
#
#   Ответ: electrical and chemical signals (Оценка: 67.8%)
#   Вопрос 3: What are the main functions of the brain?
#
#   Ответ: It controls all bodily functions and cognitive processes (Оценка: 26.8%)
# --------------------------------------------------
# Текст 10: The Mona Lisa is a famous painting by Leonardo da Vinci. It is known for its mysterious smile and is...
#   Вопрос 1: Who painted the Mona Lisa?
#
#   Ответ: Leonardo da Vinci (Оценка: 98.7%)
#   Вопрос 2: What is special about the Mona Lisa?
#
#   Ответ: mysterious smile (Оценка: 45.8%)
#   Вопрос 3: Where is the Mona Lisa displayed?
#   Ответ: Louvre Museum (Оценка: 40.7%)
# --------------------------------------------------

# %%
#Задание 3

# Загрузка модели MiniLM и токенизатора
model_id_minilm = 'bert-large-uncased-whole-word-masking-finetuned-squad'  # Заменяем модель
tokenizer_minilm = AutoTokenizer.from_pretrained(model_id_minilm)
model_minilm = TFAutoModelForQuestionAnswering.from_pretrained(model_id_minilm, from_pt=True)
qa_pipeline_minilm = pipeline('question-answering', model=model_minilm, tokenizer=tokenizer_minilm)

# Создание TF-IDF векторизатора
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(contexts)

# Функция для выбора наиболее релевантных контекстов (TF-IDF)
def get_best_contexts_tfidf(query, contexts, vectorizer, max_matches=5):  # Увеличиваем количество контекстов до 5
    query_vector = vectorizer.transform([query])
    scores = cosine_similarity(query_vector, tfidf_matrix).flatten()
    top_indices = scores.argsort()[-max_matches:][::-1]
    return [contexts[idx] for idx in top_indices]

# Функция для вывода ответов
def show_answers_tfidf(questions, contexts, vectorizer):
    for i, question in enumerate(questions):
        best_contexts = get_best_contexts_tfidf(question, contexts, vectorizer)
        print(f"Вопрос {i + 1}: {question}")
        found_answer = False
        for context in best_contexts:
            output = qa_pipeline_minilm(question=question, context=context, handle_impossible_answer=True)
            if output['start'] != output['end']:
                print(f"  Ответ: {output['answer']} (Оценка: {output['score']:.1%})")
                found_answer = True
        if not found_answer:
            print("  Нет ответа")
        print("-" * 50)

# Тестирование TF-IDF извлекателя
all_questions = questions_1 + questions_2 + questions_3
show_answers_tfidf(all_questions, contexts, vectorizer)
# Out:
# All PyTorch model weights were used when initializing TFBertForQuestionAnswering.
#
# All the weights of TFBertForQuestionAnswering were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertForQuestionAnswering for predictions without further training.
# Device set to use 0
# Вопрос 1: What is the sun?
#   Ответ: the star at the center of our solar system (Оценка: 63.2%)
#   Ответ: mysterious smile (Оценка: 8.9%)
#   Ответ: Pacific Ocean is the largest and deepest ocean on Earth (Оценка: 5.9%)
#   Ответ: Eiffel Tower (Оценка: 2.3%)
#   Ответ: oxygen (Оценка: 13.4%)
# --------------------------------------------------
# Вопрос 2: What is the largest land animal?
#   Ответ: Elephants (Оценка: 99.9%)
#   Ответ: Pacific Ocean (Оценка: 13.2%)
#   Ответ: The Mona Lisa (Оценка: 11.0%)
#   Ответ: The sun (Оценка: 13.6%)
# --------------------------------------------------
# Вопрос 3: When was the Eiffel Tower completed?
#
#   Ответ: 1889 (Оценка: 99.4%)
#   Ответ: 7th century BC (Оценка: 40.1%)
#   Ответ: nuclear fusion. (Оценка: 3.2%)
#   Ответ: Shakespeare (Оценка: 1.8%)
#   Ответ: oxygen (Оценка: 2.6%)
# --------------------------------------------------
# Вопрос 4: At what temperature does water boil at sea level?
#
#   Ответ: 100°C (Оценка: 99.6%)
#   Ответ: nuclear fusion (Оценка: 2.1%)
#   Ответ: chemical signals. It controls all bodily functions and cognitive processes. (Оценка: 5.2%)
#   Ответ: Pacific Ocean is the largest and deepest (Оценка: 5.1%)
# --------------------------------------------------
# Вопрос 5: Where is the Amazon Rainforest located?
#   Ответ: Amazon (Оценка: 76.9%)
#   Ответ: Paris (Оценка: 30.5%)
#   Ответ: Earth (Оценка: 6.9%)
#   Ответ: Pacific Ocean (Оценка: 12.3%)
#   Ответ: Paris (Оценка: 76.1%)
# --------------------------------------------------
# Вопрос 6: How long is the Great Wall of China?
#
#   Ответ: 13,000 miles (Оценка: 77.2%)
#   Ответ: oxygen. (Оценка: 1.8%)
#   Ответ: nuclear fusion. (Оценка: 2.3%)
#   Ответ: Paris. (Оценка: 2.9%)
#   Ответ: 1889 as the entrance arch for the World's Fair in Paris. (Оценка: 3.1%)
# --------------------------------------------------
# Вопрос 7: Who was William Shakespeare?
#
#   Ответ: an English playwright and poet (Оценка: 58.8%)
#   Ответ: The Great Wall of China (Оценка: 1.8%)
#   Ответ: 1889 as the entrance arch for the World's Fair in Paris (Оценка: 2.1%)
#   Ответ: Leonardo da Vinci (Оценка: 3.4%)
#   Ответ: . (Оценка: 1.7%)
# --------------------------------------------------
# Вопрос 8: What is the largest ocean on Earth?
#   Ответ: The Pacific Ocean (Оценка: 55.5%)
#   Ответ: Earth through a process called nuclear fusion. (Оценка: 2.7%)
#   Ответ: Elephants (Оценка: 53.9%)
#   Ответ: Amazon (Оценка: 55.5%)
#   Ответ: Paris. (Оценка: 2.3%)
# --------------------------------------------------
# Вопрос 9: What does the human brain consist of?
