# %% [markdown]
# ## Доработать блокнот
#
# ### Задача 1. Стиль-трансфер диалогов в разные эпохи
# #### Постановка
# Необходимо преобразовать современный диалог в стиле «XXI века» к диалогу другой эпохи (например, рубежа XIX–XX вв.) или жанра (фэнтези, научная фантастика и т.д.), сохранив при этом общий смысл исходной беседы.
# #### Стартовый датасет
#     • DailyDialog — содержит повседневные короткие диалоги. Его можно дополнить собственным корпусом литературы или сценариев разных эпох (например, тексты из Project Gutenberg).
# #### Метрики
#     1. BLEU / ROUGE / BERTScore: Оценка схожести с «целью» стилевого трансфера (при наличии эталонных примеров).
#     2. Content Preservation: Специальные метрики (часто основанные на similar sentence embeddings), чтобы проверить, сохраняется ли исходный смысл.
#     3. Style Accuracy: Классификатор стиля (обученный отдельно на текстах целевой эпохи/жанра) оценивает, насколько успешно изменён стиль.

# %%
# =============================================
# Пример кода для Задания 2: "Стиль-трансфер диалогов"
# =============================================
# -------------------------
# Шаг 0. Установка библиотек
# -------------------------
# В средах вроде Google Colab можно раскомментировать команду !pip install ...
# В Jupyter на локальном компьютере установите необходимые пакеты вручную.

# !pip install transformers datasets sentencepiece
# !pip install rouge-score
# !pip install sacrebleu
# !pip install bert-score
# Out:
# Requirement already satisfied: transformers in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (4.48.0)
# Requirement already satisfied: datasets in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (3.2.0)
# Requirement already satisfied: sentencepiece in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (0.2.0)
# Requirement already satisfied: filelock in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from transformers) (0.27.1)
# Requirement already satisfied: numpy>=1.17 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from transformers) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from datasets) (2.2.3)
# Requirement already satisfied: xxhash in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from datasets) (3.11.11)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: rouge-score in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (0.1.2)
# Requirement already satisfied: absl-py in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from rouge-score) (2.1.0)
# Requirement already satisfied: nltk in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: numpy in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from rouge-score) (2.2.3)
# Requirement already satisfied: six>=1.14.0 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: click in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from nltk->rouge-score) (8.1.7)
# Requirement already satisfied: joblib in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from nltk->rouge-score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from nltk->rouge-score) (2024.11.6)
# Requirement already satisfied: tqdm in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from nltk->rouge-score) (4.67.1)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: sacrebleu in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (2.5.1)
# Requirement already satisfied: portalocker in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from sacrebleu) (3.1.1)
# Requirement already satisfied: regex in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from sacrebleu) (2024.11.6)
# Requirement already satisfied: tabulate>=0.8.9 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from sacrebleu) (2.2.3)
# Requirement already satisfied: colorama in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from sacrebleu) (5.3.1)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: bert-score in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (0.3.13)
# Requirement already satisfied: torch>=1.0.0 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from bert-score) (2.5.1)
# Requirement already satisfied: pandas>=1.0.1 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from bert-score) (2.2.3)
# Requirement already satisfied: transformers>=3.0.0 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from bert-score) (4.48.0)
# Requirement already satisfied: numpy in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from bert-score) (2.2.3)
# Requirement already satisfied: requests in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from bert-score) (2.32.3)
# Requirement already satisfied: tqdm>=4.31.1 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from bert-score) (4.67.1)
# Requirement already satisfied: matplotlib in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from bert-score) (3.10.0)
# Requirement already satisfied: packaging>=20.9 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from bert-score) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from pandas>=1.0.1->bert-score) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from pandas>=1.0.1->bert-score) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from pandas>=1.0.1->bert-score) (2024.2)
# Requirement already satisfied: filelock in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from torch>=1.0.0->bert-score) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from torch>=1.0.0->bert-score) (4.12.2)
# Requirement already satisfied: networkx in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from torch>=1.0.0->bert-score) (3.4.2)
# Requirement already satisfied: jinja2 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from torch>=1.0.0->bert-score) (3.1.5)
# Requirement already satisfied: fsspec in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from torch>=1.0.0->bert-score) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from torch>=1.0.0->bert-score) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from torch>=1.0.0->bert-score) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from torch>=1.0.0->bert-score) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from torch>=1.0.0->bert-score) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from torch>=1.0.0->bert-score) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from torch>=1.0.0->bert-score) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from torch>=1.0.0->bert-score) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from torch>=1.0.0->bert-score) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from torch>=1.0.0->bert-score) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from torch>=1.0.0->bert-score) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from torch>=1.0.0->bert-score) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from torch>=1.0.0->bert-score) (12.4.127)
# Requirement already satisfied: setuptools in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from torch>=1.0.0->bert-score) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from torch>=1.0.0->bert-score) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from sympy==1.13.1->torch>=1.0.0->bert-score) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from transformers>=3.0.0->bert-score) (0.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from transformers>=3.0.0->bert-score) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from transformers>=3.0.0->bert-score) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from transformers>=3.0.0->bert-score) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from transformers>=3.0.0->bert-score) (0.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from matplotlib->bert-score) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from matplotlib->bert-score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from matplotlib->bert-score) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from matplotlib->bert-score) (1.4.8)
# Requirement already satisfied: pillow>=8 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from matplotlib->bert-score) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from matplotlib->bert-score) (3.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from requests->bert-score) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from requests->bert-score) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from requests->bert-score) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from requests->bert-score) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert-score) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/oli/miniconda3/envs/llmenv/lib/python3.13/site-packages (from jinja2->torch>=1.0.0->bert-score) (3.0.2)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline
from rouge_score import rouge_scorer
import sacrebleu
from bert_score import score

# %%
# =============================================
# Шаг 1. Подготовка данных
# =============================================
# Представим, что у нас есть небольшой набор "современных" диалогов,
# и мы хотим перевести их в стиль "старой/архаичной" английской речи (условный пример).

data = [
    {
        "modern_dialog": "Hey, how are you doing today? Everything going well?",
        # "reference_style" - эталонная фраза в нужном стиле (для метрик)
        "reference_style": "Greetings, how dost thou fare this day? All proceedeth well?"
    },
    {
        "modern_dialog": "Hello sir, can you tell me where the library is?",
        "reference_style": "Good morrow, couldst thou direct me to the grand library?"
    }
]

# %%
# =============================================
# Шаг 2. Загрузка модели для стиль-трансфера
# =============================================
# Для демонстрации используем модель T5 (англоязычную).
# В реальном проекте потребуется дообучение (fine-tuning) на корпусе "старинной" речи.
# Здесь просто показываем принцип: подача на вход промпта с задачей "transfer to old english style: ..."

model_name = "t5-small"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
# Out:
# model.safetensors:   9%|8         | 21.0M/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
# =============================================
# Шаг 3. Генерация преобразованных диалогов
# =============================================
generated_texts = []

for item in data:
    prompt = f"translate to old english style: {item['modern_dialog']}"
    inputs = tokenizer.encode(prompt, return_tensors="pt", max_length=512, truncation=True)

    # Генерация
    outputs = model.generate(
        inputs,
        max_length=50,
        num_beams=4,
        early_stopping=True
    )

    styled_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

    generated_texts.append({
        "modern_dialog": item["modern_dialog"],
        "styled_text": styled_text,
        "reference_style": item["reference_style"]
    })

# %%
# =============================================
# Шаг 4. Вывод результатов
# =============================================
print("=== Результаты стиль-трансфера ===\n")
for idx, res in enumerate(generated_texts):
    print(f"Modern dialog:      {res['modern_dialog']}")
    print(f"Generated (styled): {res['styled_text']}")
    print(f"Reference style:    {res['reference_style']}")
    print("-" * 80)
# Out:
# === Результаты стиль-трансфера ===
#
# Modern dialog:      Hey, how are you doing today? Everything going well?
# Generated (styled): Hey, how are you doing today?
# Reference style:    Greetings, how dost thou fare this day? All proceedeth well?
# --------------------------------------------------------------------------------
# Modern dialog:      Hello sir, can you tell me where the library is?
# Generated (styled): Hello sir, can you tell me where the library is?
# Reference style:    Good morrow, couldst thou direct me to the grand library?
# --------------------------------------------------------------------------------

# %%
# =============================================
# Шаг 5. Оценка по метрикам (BLEU, ROUGE, BERTScore)
# =============================================
# Подготовим списки предсказаний и эталонов для метрик
predictions = [r["generated_backstory"] for r in generated_results]
references = [r["reference_backstory"] for r in generated_results]

# Загружаем метрики
rouge = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)

# a dictionary that will contain the results
results = {'precision': [], 'recall': [], 'fmeasure': []}

# for each of the hypothesis and reference documents pair
for (h, r) in zip(predictions, references):
    # computing the ROUGE
    rouge_score = rouge.score(h, r)
    # separating the measurements
    precision, recall, fmeasure = rouge_score['rouge1']
    # add them to the proper list in the dictionary
    results['precision'].append(precision)
    results['recall'].append(recall)
    results['fmeasure'].append(fmeasure)
# Out:
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.21 seconds, 9.37 sentences/sec

# %%
# =============================================
# Шаг 6. Content Preservation
# =============================================
# Для упрощённой оценки сохранившегося смысла сравним с "исходным" текстом.
# Снова используем BERTScore, но теперь "reference" = modern_dialog.
# Out:
# calculating scores...
# computing bert embedding.
#   0%|          | 0/1 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/1 [00:00<?, ?it/s]
# done in 0.02 seconds, 102.10 sentences/sec
# BERTScore Precision: 0.6125 Recall: 0.5484 F1 Score: 0.5782

# %%
# =============================================
# Шаг 7. Style Accuracy
# =============================================
# Для строгой оценки "насколько текст выглядит стилизованным под староанглийский"
# обычно тренируют или используют готовый классификатор стилей (модель для text-classification).
# Здесь сделаем упрощённый "заглушечный" пример.

# Допустим, у нас есть условный простейший классификатор, который считает, что
# если текст содержит "thou", "thee", "dost" и т.д., это "old english", иначе "modern".
# В реальном проекте нужно собрать датасет и обучить/использовать модель.

def dummy_style_classifier(text: str) -> str:
    # Если находит хотя бы одно "староанглийское" слово, предполагаем класс "old_english", иначе "modern"


style_predictions = ...

# вывод результатов

# В реальном случае подсчитываем точность:
accuracy = ...
print(f"Style Accuracy: {accuracy:.2f}")
# Out:
# === Style Accuracy (упрощённый пример) ===
# Text: Hey, how are you doing today?
# Predicted style: modern
# -----
# Text: Hello sir, can you tell me where the library is?
# Predicted style: modern
# -----
# Style Accuracy: 0.00

# %%
# =============================================
# Шаг 8. Итоги
# =============================================
print("\n=== Вывод ===")
print("В примере выше показана базовая демонстрация использования T5 для 'стиль-трансфера'.")
print("В реальных задачах рекомендуется:")
print("  - Собрать и разметить датасет примеров старинной речи и её соответствий.")
print("  - Выполнить дообучение модели (fine-tuning).")
print("  - Использовать полноценный классификатор стиля, обученный на стилизованных текстах.")
print("  - Проводить ручную оценку (human evaluation) для проверки качества переноса стиля.")
# Out:
# === Вывод ===
# В примере выше показана базовая демонстрация использования T5 для 'стиль-трансфера'.
# В реальных задачах рекомендуется:
#   - Собрать и разметить датасет примеров старинной речи и её соответствий.
#   - Выполнить дообучение модели (fine-tuning).
#   - Использовать полноценный классификатор стиля, обученный на стилизованных текстах.
#   - Проводить ручную оценку (human evaluation) для проверки качества переноса стиля.
